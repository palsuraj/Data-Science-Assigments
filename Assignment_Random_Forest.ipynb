# %% [markdown]
# <a href="https://colab.research.google.com/github/YG-0/Datascience_assisgnments/blob/main/Assignment_Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Company Check**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/content/Company_Data (1).csv")

# %%
df.head()
# Out:
#    Sales  CompPrice  Income  Advertising  ...  Age  Education Urban   US
# 0   9.50        138      73           11  ...   42         17   Yes  Yes
# 1  11.22        111      48           16  ...   65         10   Yes  Yes
# 2  10.06        113      35           10  ...   59         12   Yes  Yes
# 3   7.40        117     100            4  ...   55         14   Yes  Yes
# 4   4.15        141      64            3  ...   38         13   Yes   No
#
# [5 rows x 11 columns]

# %%
df.tail()
# Out:
#      Sales  CompPrice  Income  Advertising  ...  Age  Education Urban   US
# 395  12.57        138     108           17  ...   33         14   Yes  Yes
# 396   6.14        139      23            3  ...   55         11    No  Yes
# 397   7.41        162      26           12  ...   40         18   Yes  Yes
# 398   5.94        100      79            7  ...   50         12   Yes  Yes
# 399   9.71        134      37            0  ...   49         16   Yes  Yes
#
# [5 rows x 11 columns]

# %%
df = pd.get_dummies(df)

# %%
df.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'Age', 'Education', 'ShelveLoc_Bad', 'ShelveLoc_Good',
#        'ShelveLoc_Medium', 'Urban_No', 'Urban_Yes', 'US_No', 'US_Yes'],
#       dtype='object')

# %%
df.corr()
# Out:
#                      Sales  CompPrice    Income  ...  Urban_Yes     US_No    US_Yes
# Sales             1.000000   0.064079  0.151951  ...  -0.015419 -0.177093  0.177093
# CompPrice         0.064079   1.000000 -0.080653  ...   0.066594 -0.016869  0.016869
# Income            0.151951  -0.080653  1.000000  ...   0.037967 -0.089601  0.089601
# Advertising       0.269507  -0.024199  0.058995  ...   0.042035 -0.684460  0.684460
# Population        0.050471  -0.094707 -0.007877  ...  -0.052025 -0.060564  0.060564
# Price            -0.444951   0.584848 -0.056698  ...   0.047016 -0.057861  0.057861
# Age              -0.231815  -0.100239 -0.004670  ...   0.028479 -0.008652  0.008652
# Education        -0.051955   0.025197 -0.056855  ...  -0.033094  0.078250 -0.078250
# ShelveLoc_Bad    -0.393167  -0.035393  0.072017  ...   0.081122 -0.000979  0.000979
# ShelveLoc_Good    0.500510   0.026386 -0.012657  ...  -0.039197 -0.078864  0.078864
# ShelveLoc_Medium -0.073999   0.008683 -0.051392  ...  -0.037391  0.065656 -0.065656
# Urban_No          0.015419  -0.066594 -0.037967  ...  -1.000000  0.047085 -0.047085
# Urban_Yes        -0.015419   0.066594  0.037967  ...   1.000000 -0.047085  0.047085
# US_No            -0.177093  -0.016869 -0.089601  ...  -0.047085  1.000000 -1.000000
# US_Yes            0.177093   0.016869  0.089601  ...   0.047085 -1.000000  1.000000
#
# [15 rows x 15 columns]

# %%
df.drop(['US_No','ShelveLoc_Medium','Urban_No','Urban_Yes','Education','Population'],inplace=True,axis=1)

# %%
X = df.drop('Sales',axis=1)
y = df['Sales']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled_train = scaler.fit_transform(X_train)

X_scaled_test = scaler.transform(X_test)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtree_reg = DecisionTreeRegressor()
dtree_reg.fit(X_scaled_train,y_train)
print(dtree_reg.feature_importances_)
# Out:
# [0.12438406 0.06336785 0.09061437 0.31953187 0.07525459 0.04381365
#  0.26246436 0.02056926]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV, KFold , RandomizedSearchCV

# %%
rfr = RandomForestRegressor()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
min_samples_split = [3,4,5,6,7,8]
max_depth = [3,4,5,6,7]
max_features = [None,3,4,5]
n_estimators = [90,100,125,150,200]
n_jobs =[-1]

param_grid = dict(n_estimators = n_estimators, n_jobs = n_jobs, min_samples_split = min_samples_split,max_depth = max_depth,max_features= max_features,)

grid = GridSearchCV(estimator = rfr,param_grid = param_grid,cv = KFold(n_splits=5,shuffle=True), verbose = 10)
grid_result = grid.fit(X_scaled_train,y_train)
# Out:
# Fitting 5 folds for each of 600 candidates, totalling 3000 fits
# [CV] max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1, score=0.234, total=   1.5s
# [CV] max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [CV]  max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1, score=0.548, total=   0.4s
# [CV] max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.9s remaining:    0.0s
# [CV]  max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1, score=0.606, total=   0.4s
# [CV] max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.3s remaining:    0.0s
# [CV]  max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1, score=0.522, total=   0.3s
# [CV] max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    2.6s remaining:    0.0s
# [CV]  max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1, score=0.500, total=   0.3s
# [CV] max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.9s remaining:    0.0s
# [CV]  max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1, score=0.245, total=   0.3s
# [CV] max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    3.3s remaining:    0.0s
# [CV]  max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1, score=0.534, total=   0.3s
# [CV] max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    3.6s remaining:    0.0s
# [CV]  max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1, score=0.605, total=   0.3s
# [CV] max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    3.9s remaining:    0.0s
# [CV]  max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1, score=0.512, total=   0.3s
# [CV] max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    4.3s remaining:    0.0s
# Streaming output truncated to the last 5000 lines.
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=90, n_jobs=-1, score=0.284, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=90, n_jobs=-1, score=0.537, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=90, n_jobs=-1, score=0.596, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=90, n_jobs=-1, score=0.518, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=90, n_jobs=-1, score=0.501, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=100, n_jobs=-1, score=0.285, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=100, n_jobs=-1, score=0.504, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=100, n_jobs=-1, score=0.604, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=100, n_jobs=-1, score=0.536, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=100, n_jobs=-1, score=0.505, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=125, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=125, n_jobs=-1, score=0.314, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=125, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=125, n_jobs=-1, score=0.535, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=125, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=125, n_jobs=-1, score=0.614, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=125, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=125, n_jobs=-1, score=0.526, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=125, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=125, n_jobs=-1, score=0.513, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=150, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=150, n_jobs=-1, score=0.315, total=   0.4s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=150, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=150, n_jobs=-1, score=0.521, total=   0.4s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=150, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=150, n_jobs=-1, score=0.609, total=   0.4s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=150, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=150, n_jobs=-1, score=0.529, total=   0.4s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=150, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=150, n_jobs=-1, score=0.494, total=   0.4s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1, score=0.301, total=   0.5s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1, score=0.515, total=   0.5s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1, score=0.614, total=   0.5s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1, score=0.537, total=   0.5s
# [CV] max_depth=3, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1, score=0.507, total=   0.5s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1, score=0.289, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1, score=0.504, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1, score=0.606, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1, score=0.519, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1, score=0.500, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1, score=0.337, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1, score=0.509, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1, score=0.603, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1, score=0.536, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1, score=0.511, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1, score=0.309, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1, score=0.513, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1, score=0.599, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1, score=0.535, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1, score=0.511, total=   0.3s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1, score=0.278, total=   0.4s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1, score=0.530, total=   0.4s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1, score=0.615, total=   0.4s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1, score=0.528, total=   0.4s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1, score=0.517, total=   0.4s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1, score=0.301, total=   0.5s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1, score=0.530, total=   0.5s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1, score=0.614, total=   0.5s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1, score=0.532, total=   0.5s
# [CV] max_depth=3, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV]  max_depth=3, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-
total=   0.3s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1, score=0.391, total=   0.3s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1, score=0.600, total=   0.3s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1, score=0.640, total=   0.4s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1, score=0.570, total=   0.3s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1, score=0.592, total=   0.3s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1, score=0.359, total=   0.4s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1, score=0.598, total=   0.4s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1, score=0.641, total=   0.4s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1, score=0.591, total=   0.4s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1, score=0.581, total=   0.4s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1, score=0.364, total=   0.5s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1, score=0.610, total=   0.5s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1, score=0.654, total=   0.5s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1, score=0.581, total=   0.5s
# [CV] max_depth=4, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1, score=0.575, total=   0.5s
# [CV] max_depth=4, max_features=None, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=8, n_estimators=90, n_jobs=-1, score=0.384, total=   0.3s
# [CV] max_depth=4, max_features=None, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV]  max_depth=4, max_features=None, min_samples_split=8, n_estimators=90, n_jobs=-1, score=0.595, total=   0.3s
# ...
# [CV] max_depth=7, max_features=5, min_samples_split=5, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=5, n_estimators=150, n_jobs=-1, score=0.654, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1, score=0.579, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1, score=0.643, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1, score=0.711, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1, score=0.696, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=5, n_estimators=200, n_jobs=-1, score=0.650, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1, score=0.575, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1, score=0.646, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1, score=0.721, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1, score=0.679, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1, score=0.648, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1, score=0.594, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1, score=0.673, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1, score=0.721, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1, score=0.667, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1, score=0.645, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1, score=0.564, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1, score=0.659, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1, score=0.691, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1, score=0.681, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1, score=0.663, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1, score=0.553, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1, score=0.646, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1, score=0.703, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1, score=0.681, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1, score=0.655, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1, score=0.563, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1, score=0.652, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1, score=0.714, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1, score=0.692, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1, score=0.657, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1, score=0.535, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1, score=0.652, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1, score=0.712, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1, score=0.691, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1, score=0.645, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1, score=0.567, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1, score=0.676, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1, score=0.697, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1, score=0.696, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1, score=0.673, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1, score=0.569, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1, score=0.660, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1, score=0.695, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1, score=0.691, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1, score=0.652, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1, score=0.567, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1, score=0.646, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1, score=0.709, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1, score=0.689, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1, score=0.647, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1, score=0.554, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1, score=0.666, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1, score=0.695, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1, score=0.679, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1, score=0.644, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1, score=0.557, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1, score=0.662, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1, score=0.684, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1, score=0.685, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1, score=0.653, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1, score=0.537, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1, score=0.653, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1, score=0.719, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1, score=0.671, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1, score=0.638, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1, score=0.562, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1, score=0.655, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1, score=0.695, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1, score=0.682, total=   0.3s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1, score=0.649, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1, score=0.566, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1, score=0.667, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1, score=0.680, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1, score=0.672, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1, score=0.655, total=   0.4s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1, score=0.574, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1, score=0.659, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1, score=0.693, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1, score=0.677, total=   0.5s
# [CV] max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV]  max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1, score=0.647, total=   0.5s
# [Parallel(n_jobs=1)]: Done 3000 out of 3000 | elapsed: 19.4min finished

# %%
grid_result.best_params_
# Out:
# {'max_depth': 7,
#  'max_features': None,
#  'min_samples_split': 3,
#  'n_estimators': 125,
#  'n_jobs': -1}

# %%
rfr = RandomForestRegressor(n_estimators=100,max_depth=7, max_features=5, min_samples_split=3,n_jobs=-1)

# %%
rfr.fit(X_scaled_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=7, max_features=5, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=3, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rfr.score(X_scaled_test,y_test)
# Out:
# 0.6903035083469969

# %%
prediction = rfr.predict(X_scaled_test)

# %%
from sklearn.metrics import mean_squared_error
rms = mean_squared_error(y_test, prediction, squared=True)

# %%
len(y_test)
# Out:
# 132

# %%
(prediction[1] - y_test.iloc[1])
# Out:
# -1.2998320702662518

# %%
y_test.iloc[1]
# Out:
# 8.67

# %%
def mean_squared_error(predict,actual):
    sum =0
    for i in range(len(predict)):
        sum = sum + (prediction[1] - y_test.iloc[1]) * (prediction[1] - y_test.iloc[1])
        
    return sum/len(predict)

# %%
ssr = mean_squared_error(prediction,y_test)

# %%
print(f"Sum of squared residual: {ssr}")
# Out:
# Sum of squared residual: 1.6895634108926474

# %% [markdown]
# ### **Fraud Check**

# %%
df = pd.read_csv("/content/Fraud_check (1).csv")

# %%
df.head()

# %%
df['Taxable.Income'] =  ['Risky' if x<=30000 else 'Good' for x in df['Taxable.Income']]

# %%
df.head()

# %%
df['Taxable.Income'].value_counts()

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df.corr()

# %%
plt.figure(figsize=(11,7))
sns.countplot(x='Taxable.Income_Risky',hue='Undergrad_YES',data=df,palette='Set1')

# %%
plt.figure(figsize=(11,7))
sns.countplot(x='Taxable.Income_Risky',hue='Marital.Status_Married',data=df,palette='Set1')

# %%
X = df.drop('Taxable.Income_Risky',axis=1)
y = df['Taxable.Income_Risky']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled_train = scaler.fit_transform(X_train)

X_scaled_test = scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import GridSearchCV, KFold , RandomizedSearchCV

# %%
rfc = RandomForestClassifier()

# %%
min_samples_split = [12,13,14,15,16,17,18,19,20]
max_depth = [3,4,5,6]
max_features = [3,4]
min_impurity_split=[0.15,0.20,0.25]
n_estimators=[100,150,180,200]
n_jobs=[-1]


param_grid = dict(n_estimators=n_estimators,n_jobs=n_jobs,min_samples_split = min_samples_split,max_depth = max_depth,
                  max_features= max_features,min_impurity_split=min_impurity_split)

grid = GridSearchCV(estimator = rfc,param_grid = param_grid,cv = KFold(n_splits=5,shuffle=True), verbose = 10)
grid_result = grid.fit(X_scaled_train,y_train)

# %%
grid_result.best_estimator_

# %%
rfc = RandomForestClassifier(max_depth=3, max_features=3, min_impurity_split=0.15,
                       min_samples_split=12, n_jobs=-1)

# %%
rfc.fit(X_scaled_train,y_train)

# %%
print(rfc.feature_importances_)

# %%
X_train_new = X_scaled_train[:,[0,1,3]]
X_test_new = X_scaled_test[:,[0,1,3]]

# %%
rfc.fit(X_train_new,y_train)

# %%
predict = rfc.predict(X_test_new)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predict))

print(confusion_matrix(y_test,predict))

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler()

# %%
X_train_res, y_train_res = ros.fit_resample(X_train_new, y_train)

# %%
rfc.fit(X_train_res,y_train_res)

# %%
probs_y = rfc.predict_proba(X_test_new)

# %%
from sklearn.metrics import precision_recall_curve
precision, recall, thresholds = precision_recall_curve(y_test, probs_y[:, 1]) 

plt.title("Precision-Recall vs Threshold Chart")
plt.plot(thresholds, precision[: -1], "b--", label="Precision")
plt.plot(thresholds, recall[: -1], "r--", label="Recall")
plt.ylabel("Precision, Recall")
plt.xlabel("Threshold")
plt.legend(loc="lower left")

plt.ylim([0,1])

# %%
model = probs_y[:,1]
model = [1 if x>=0.45 else 0 for x in model]


print(classification_report(y_test,model))

print(confusion_matrix(y_test,model))
